# %% [markdown]
# # Construting NN to predict Nitrate Concentration using Temporal Variables
# # Temporal variables include (year, season and month)

# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Dataset preprocessing

# %%
df = pd.read_csv("test_steven_temporal.csv")
df.head()
# Out:
#    User ID  Sample ID      Date Created      Date changed       Sample Date  \
# 0    14663      19524  18/01/2018 17:45  18/01/2018 17:45  10/06/2015 08:34
# 1    14117      18161  18/01/2018 17:45  18/01/2018 17:45  14/09/2015 00:00
# 2    14117      18165  18/01/2018 17:45  18/01/2018 17:45  14/09/2015 00:00
# 3    14019      18168  18/01/2018 17:45  18/01/2018 17:45  14/09/2015 07:45
# 4    14019      18169  18/01/2018 17:45  18/01/2018 17:45  14/09/2015 07:55
#
#    year  month  1Spring/2Autumn which.blitz                       Group ID  \
# 0  2015      6                1           1  Thames Blitz, Group ID: 34343
# 1  2015      9                2           1  Thames Blitz, Group ID: 34343
# 2  2015      9                2           1  Thames Blitz, Group ID: 34343
# 3  2015      9                2           1  Thames Blitz, Group ID: 34343
# 4  2015      9                2           1  Thames Blitz, Group ID: 34343
#
#    ...  Longitude) Total number of participants   \
# 0  ...   -1.076161                          27.0
# 1  ...   -1.565350                           1.0
# 2  ...   -1.674520                           1.0
# 3  ...   -1.656125                           1.0
# 4  ...   -1.657519                           1.0
#
#                                                Notes  Freshwater body type  \
# 0  The Year 4 class helped with the Totally Thame...                 River
# 1                                                NaN                Stream
# 2                                                NaN                 River
# 3  House about 200 yards above it. Uncultivated g...                Stream
# 4                 signs of cows in and around stream                Stream
#
#    Other What is the land use in the immediate surroundings?  \
# 0    NaN                                                NaN
# 1    NaN                                                NaN
# 2    NaN                                                NaN
# 3    NaN                                                NaN
# 4    NaN                                                NaN
#
#   What is the bank vegetation? (select all that apply)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Is there any of the following on the water surface? Nitrate Phosphate
# 0                                                NaN      0.1     0.010
# 1                                                NaN     12.0     0.075
# 2                                                NaN     12.0     0.075
# 3                                                NaN      7.5     0.150
# 4                                                NaN      7.5     0.010
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2361 entries, 0 to 2360
# Data columns (total 23 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   User ID                                               2361 non-null   int64
#  1   Sample ID                                             2361 non-null   int64
#  2   Date Created                                          2361 non-null   object
#  3   Date changed                                          2361 non-null   object
#  4   Sample Date                                           2361 non-null   object
#  5   year                                                  2361 non-null   int64
#  6   month                                                 2361 non-null   int64
#  7   1Spring/2Autumn                                       2361 non-null   int64
#  8   which.blitz                                           2351 non-null   object
#  9   Group ID                                              2361 non-null   object
#  10  Site name                                             2361 non-null   object
#  11  Sample date/time                                      2361 non-null   object
#  12  Geolocation (Latitude                                 2328 non-null   float64
#  13   Longitude)                                           2328 non-null   float64
#  14  Total number of participants                          2155 non-null   float64
#  15  Notes                                                 1108 non-null   object
#  16  Freshwater body type                                  2333 non-null   object
#  17  Other                                                 229 non-null    object
#  18  What is the land use in the immediate surroundings?   1362 non-null   object
#  19  What is the bank vegetation? (select all that apply)  1354 non-null   object
#  20  Is there any of the following on the water surface?   218 non-null    object
#  21  Nitrate                                               2361 non-null   float64
#  22  Phosphate                                             2361 non-null   float64
# dtypes: float64(5), int64(5), object(13)
# memory usage: 424.4+ KB

# %%
# using Temporal input data to predict Nitrate concentration
df_final = df[["Nitrate","year","month","1Spring/2Autumn"]]

# %%
# Converting all columns to float
df_final = df_final.astype(float)

# %%
df_final.dtypes
# Out:
# Nitrate            float64
# year               float64
# month              float64
# 1Spring/2Autumn    float64
# dtype: object

# %%
df_final.isnull().values.any()
# Out:
# False

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2361 entries, 0 to 2360
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Nitrate          2361 non-null   float64
#  1   year             2361 non-null   float64
#  2   month            2361 non-null   float64
#  3   1Spring/2Autumn  2361 non-null   float64
# dtypes: float64(4)
# memory usage: 73.9 KB

# %% [markdown]
# # Creating basic NN class for pytorch

# %%
class Model(nn.Module):
    
    def __init__(self, in_features=3, h1=30,h2=60,h3=120,h4=240, out_features=2361):
        super().__init__()
        self.fc1 = nn.Linear(in_features,h1)
        self.fc2 = nn.Linear(h1,h2)
        self.fc3 = nn.Linear(h2,h3)
        self.fc4 = nn.Linear(h3,h4)
        self.out = nn.Linear(h4,out_features)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = self.out(x)
        
        return x

# %%
# seeding NN with 96

torch.manual_seed(96)

model = Model()

# %% [markdown]
# # Train Test Split by setting X,y

# %%
# X = features
# y = output

X = df_final.drop("Nitrate",axis=1)
y = df_final["Nitrate"]

# %%
# Converting to numpy arrays

X = X.values
y = y.values

# %%
# Train Test Split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=96)

# %%
# Convert numpy arrays to tensors

X_train = torch.FloatTensor(X_train)
X_test = torch.FloatTensor(X_test)

y_train = torch.LongTensor(y_train)
y_test = torch.LongTensor(y_test)

# %% [markdown]
# ###### Setting Criteria NN model  error + setting the optimizer + Learning Rate

# %%
# Set criteria NN to measure the error
criterion = nn.CrossEntropyLoss()

# Optimizer (Adam) and learning rate

optimizer = torch.optim.Adam(model.parameters(),lr=0.01)

# %% [markdown]
# # Training model

# %%
# Training our model
# first set epochs = 100

epochs = 100
losses = []

for i in range(epochs):
    # Going forward and getting a prediction
    y_pred =model.forward(X_train)
    
    # Measuring the loss/error
    
    # predicted values vs the y_train values
    loss = criterion(y_pred, y_train)
    
    # Keep Track of our losses
    
    losses.append(loss.detach().numpy())
    
    # print every 10 epochs
    
    if i % 10 == 0:
        print(f"Epoch: {i} and loss: {loss}")
        
    # Taking error rate and feed it back to model through NN 
    # for fine tuning of the rates (back propagation)
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# Epoch: 0 and loss: 59.019569396972656
# Epoch: 10 and loss: 2.9200408458709717
# Epoch: 20 and loss: 1.6313960552215576
# Epoch: 30 and loss: 1.5497297048568726
# Epoch: 40 and loss: 1.544691562652588
# Epoch: 50 and loss: 1.5432989597320557
# Epoch: 60 and loss: 1.5423457622528076
# Epoch: 70 and loss: 1.5421228408813477
# Epoch: 80 and loss: 1.5421106815338135
# Epoch: 90 and loss: 1.5420864820480347

# %% [markdown]
# # Graphs using matplotlib

# %%
plt.plot(range(epochs),losses)
plt.xlabel("Epoch")
plt.ylabel("loss")
# Out:
# Text(0, 0.5, 'loss')

# %%
# Evaluating Model on Test Data set (validating model on test data)

# turning off back propagation on test

with torch.no_grad():
    # X_test are features from the test
    # y_eval will be the predictions
    y_eval = model.forward(X_test)
    
    # Find the loss or error
    loss = criterion(y_eval, y_test)

# %%
# loss in test data and training matches test value
# model seems to be performing quiet well

loss
# Out:
# tensor(1.5530)

# %%
# Evaluating how the test data set performed

correct = 0

with torch.no_grad():
    for i, data in enumerate(X_test):
        y_val = model.forward(data)
        
        
        # This will tell us what the Nitrate concentration is  
        # using temporal data from our NN
        print(f"{i+1}.) {str(y_val)} \t {y_test[i]} \t {y_val.argmax().item()} ")
        
        
        # Correct or not
        
        if y_val.argmax().item() == y_test[i]:
            correct +=1
            
    print(f"We got {correct} correct!")
# Out:
# 1.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 1 	 7
# 2.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 1 	 7
# 3.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 4.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 5.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 6.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 7.) tensor([  4.8579,   4.0129, -13.5109,  ..., -14.1374, -14.4191, -12.7073]) 	 7 	 7
# 8.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 0 	 7
# 9.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 12 	 7
# 10.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 7 	 7
# 11.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 12.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 0 	 7
# 13.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 3 	 7
# 14.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 12 	 7
# 15.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 16.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 17.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 12 	 7
# 18.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 0 	 7
# 19.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 0 	 7
# 20.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 0 	 7
# 21.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 12 	 7
# 22.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 0 	 7
# 23.) tensor([  4.9109,   4.0581, -13.6607,  ..., -14.2937, -14.5768, -12.8466]) 	 7 	 7
# 24.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 25.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 26.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 7 	 7
# 27.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 7 	 7
# 28.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 29.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 3 	 7
# 30.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 0 	 7
# 31.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 12 	 7
# 32.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 0 	 7
# 33.) tensor([  4.8819,   4.0332, -13.5788,  ..., -14.2084, -14.4911, -12.7708]) 	 3 	 7
# 34.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 12 	 7
# 35.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 1 	 7
# 36.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 7 	 7
# 37.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 12 	 7
# 38.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 39.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 7 	 7
# 40.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 41.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 3 	 7
# 42.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 43.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 12 	 7
# 44.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 1 	 7
# 45.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 46.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 12 	 7
# 47.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 12 	 7
# 48.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 1 	 7
# 49.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 1 	 7
# 50.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 0 	 7
# 51.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 1 	 7
# 52.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 1 	 7
# 53.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 3 	 7
# 54.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 0 	 7
# 55.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 7 	 7
# 56.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 0 	 7
# 57.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 0 	 7
# 58.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 0 	 7
# 59.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 0 	 7
# 60.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 12 	 7
# 61.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 3 	 7
# 62.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 63.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 0 	 7
# 64.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 1 	 7
# 65.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 66.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 12 	 7
# 67.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 0 	 7
# 68.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 12 	 7
# 69.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 12 	 7
# 70.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 3 	 7
# 71.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 12 	 7
# 72.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 12 	 7
# 73.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 7 	 7
# 74.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 3 	 7
# 75.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 76.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 77.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 3 	 7
# 78.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 0 	 7
# 79.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 12 	 7
# 80.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 81.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 82.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 83.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 84.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 0 	 7
# 85.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 86.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 0 	 7
# 87.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 88.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 3 	 7
# 89.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 7 	 7
# 90.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 7 	 7
# 91.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 12 	 7
# 92.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 7 	 7
# 93.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 0 	 7
# 94.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 7 	 7
# 95.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 7 	 7
# 96.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 7 	 7
# 97.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 3 	 7
# 98.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 99.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 100.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 0 	 7
# 101.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 7 	 7
# 102.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 1 	 7
# 103.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 3 	 7
# 104.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 12 	 7
# 105.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 7 	 7
# 106.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 0 	 7
# 107.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 12 	 7
# 108.) tensor([  4.9109,   4.0581, -13.6607,  ..., -14.2937, -14.5768, -12.8466]) 	 0 	 7
# 109.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 12 	 7
# 110.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 3 	 7
# 111.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 7 	 7
# 112.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 3 	 7
# 113.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 114.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 115.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 0 	 7
# 116.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 0 	 7
# 117.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 118.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 3 	 7
# 119.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 120.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 1 	 7
# 121.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 12 	 7
# 122.) tensor([  4.8855,   4.0362, -13.5890,  ..., -14.2190, -14.5019, -12.7803]) 	 3 	 7
# 123.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 124.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 1 	 7
# 125.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 0 	 7
# 126.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 127.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 0 	 7
# 128.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 0 	 7
# 129.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 7 	 7
# 130.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 1 	 7
# 131.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 3 	 7
# 132.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 0 	 7
# 133.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 12 	 7
# 134.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 12 	 7
# 135.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 7 	 7
# 136.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 12 	 7
# 137.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 1 	 7
# 138.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 7 	 7
# 139.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 3 	 7
# 140.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 141.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 0 	 7
# 142.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 12 	 7
# 143.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 144.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 0 	 7
# 145.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 7 	 7
# 146.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 3 	 7
# 147.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 148.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 0 	 7
# 149.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 150.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 12 	 7
# 151.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 152.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 7 	 7
# 153.) tensor([  4.8819,   4.0332, -13.5788,  ..., -14.2084, -14.4911, -12.7708]) 	 0 	 7
# 154.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 12 	 7
# 155.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 0 	 7
# 156.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 1 	 7
# 157.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 158.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 159.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 3 	 7
# 160.) tensor([  4.8579,   4.0129, -13.5109,  ..., -14.1374, -14.4191, -12.7073]) 	 1 	 7
# 161.) tensor([  4.8579,   4.0129, -13.5109,  ..., -14.1374, -14.4191, -12.7073]) 	 7 	 7
# 162.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 163.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 12 	 7
# 164.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 1 	 7
# 165.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 3 	 7
# 166.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 0 	 7
# 167.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 1 	 7
# 168.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 0 	 7
# 169.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 7 	 7
# 170.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 171.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 172.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 173.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 174.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 0 	 7
# 175.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 0 	 7
# 176.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 3 	 7
# 177.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 178.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 0 	 7
# 179.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 12 	 7
# 180.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 12 	 7
# 181.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 182.) tensor([  4.8819,   4.0332, -13.5788,  ..., -14.2084, -14.4911, -12.7708]) 	 12 	 7
# 183.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 12 	 7
# 184.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 3 	 7
# 185.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 3 	 7
# 186.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 1 	 7
# 187.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 7 	 7
# 188.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 0 	 7
# 189.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 0 	 7
# 190.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 3 	 7
# 191.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 7 	 7
# 192.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 193.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 194.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 12 	 7
# 195.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 1 	 7
# 196.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 197.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 7 	 7
# 198.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 1 	 7
# 199.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 3 	 7
# 200.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 3 	 7
# 201.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 1 	 7
# 202.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 3 	 7
# 203.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 7 	 7
# 204.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 0 	 7
# 205.) tensor([  4.8819,   4.0332, -13.5788,  ..., -14.2084, -14.4911, -12.7708]) 	 1 	 7
# 206.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 207.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 7 	 7
# 208.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 209.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 0 	 7
# 210.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 211.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 7 	 7
# 212.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 213.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 1 	 7
# 214.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 1 	 7
# 215.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 3 	 7
# 216.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 0 	 7
# 217.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 7 	 7
# 218.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 219.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 3 	 7
# 220.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 7 	 7
# 221.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 222.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 223.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 224.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 3 	 7
# 225.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 226.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 3 	 7
# 227.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 7 	 7
# 228.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 229.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 1 	 7
# 230.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 231.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 232.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 0 	 7
# 233.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 3 	 7
# 234.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 235.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 236.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 1 	 7
# 237.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 7 	 7
# 238.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 7 	 7
# 239.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 7 	 7
# 240.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 0 	 7
# 241.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 12 	 7
# 242.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 1 	 7
# 243.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 244.) tensor([  4.8819,   4.0332, -13.5788,  ..., -14.2084, -14.4911, -12.7708]) 	 7 	 7
# 245.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 1 	 7
# 246.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 1 	 7
# 247.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 248.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 12 	 7
# 249.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 0 	 7
# 250.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 251.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 3 	 7
# 252.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 7 	 7
# 253.) tensor([  4.9169,   4.0631, -13.6777,  ..., -14.3114, -14.5948, -12.8624]) 	 1 	 7
# 254.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 255.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 7 	 7
# 256.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 3 	 7
# 257.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 12 	 7
# 258.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 259.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 7 	 7
# 260.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 261.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 262.) tensor([  4.8855,   4.0362, -13.5890,  ..., -14.2190, -14.5019, -12.7803]) 	 0 	 7
# 263.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 264.) tensor([  4.8579,   4.0129, -13.5109,  ..., -14.1374, -14.4191, -12.7073]) 	 3 	 7
# 265.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 266.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 267.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 1 	 7
# 268.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 7 	 7
# 269.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 12 	 7
# 270.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 1 	 7
# 271.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 272.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 0 	 7
# 273.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 7 	 7
# 274.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 7 	 7
# 275.) tensor([  4.9061,   4.0540, -13.6471,  ..., -14.2794, -14.5624, -12.8339]) 	 3 	 7
# 276.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 277.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 7 	 7
# 278.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 12 	 7
# 279.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 7 	 7
# 280.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 0 	 7
# 281.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 282.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 0 	 7
# 283.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 284.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 0 	 7
# 285.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 12 	 7
# 286.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 12 	 7
# 287.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 288.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 0 	 7
# 289.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 3 	 7
# 290.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 291.) tensor([  4.9061,   4.0540, -13.6471,  ..., -14.2794, -14.5624, -12.8339]) 	 3 	 7
# 292.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 12 	 7
# 293.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 3 	 7
# 294.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 12 	 7
# 295.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 1 	 7
# 296.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 7 	 7
# 297.) tensor([  4.8507,   4.0067, -13.4905,  ..., -14.1161, -14.3975, -12.6883]) 	 0 	 7
# 298.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 7 	 7
# 299.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 12 	 7
# 300.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 7 	 7
# 301.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 12 	 7
# 302.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 0 	 7
# 303.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 12 	 7
# 304.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 305.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 0 	 7
# 306.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 307.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 1 	 7
# 308.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 309.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 0 	 7
# 310.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 311.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 312.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 3 	 7
# 313.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 12 	 7
# 314.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 12 	 7
# 315.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 0 	 7
# 316.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 317.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 12 	 7
# 318.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 0 	 7
# 319.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 3 	 7
# 320.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 0 	 7
# 321.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 322.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 323.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 3 	 7
# 324.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 12 	 7
# 325.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 3 	 7
# 326.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 0 	 7
# 327.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 0 	 7
# 328.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 12 	 7
# 329.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 7 	 7
# 330.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 7 	 7
# 331.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 0 	 7
# 332.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 12 	 7
# 333.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 334.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 12 	 7
# 335.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 0 	 7
# 336.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 337.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 338.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 0 	 7
# 339.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 1 	 7
# 340.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 7 	 7
# 341.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 12 	 7
# 342.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 3 	 7
# 343.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 344.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 345.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 12 	 7
# 346.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 3 	 7
# 347.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 3 	 7
# 348.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 0 	 7
# 349.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 1 	 7
# 350.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 1 	 7
# 351.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 352.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 0 	 7
# 353.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 354.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 355.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 3 	 7
# 356.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 1 	 7
# 357.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 1 	 7
# 358.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 359.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 360.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 0 	 7
# 361.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 7 	 7
# 362.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 3 	 7
# 363.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 364.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 7 	 7
# 365.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 3 	 7
# 366.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 3 	 7
# 367.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 7 	 7
# 368.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 369.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 3 	 7
# 370.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 0 	 7
# 371.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 372.) tensor([  4.8855,   4.0362, -13.5890,  ..., -14.2190, -14.5019, -12.7803]) 	 1 	 7
# 373.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 3 	 7
# 374.) tensor([  4.8855,   4.0362, -13.5890,  ..., -14.2190, -14.5019, -12.7803]) 	 1 	 7
# 375.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 376.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 12 	 7
# 377.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 0 	 7
# 378.) tensor([  4.8819,   4.0332, -13.5788,  ..., -14.2084, -14.4911, -12.7708]) 	 7 	 7
# 379.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 12 	 7
# 380.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 381.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 1 	 7
# 382.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 0 	 7
# 383.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 384.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 0 	 7
# 385.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 3 	 7
# 386.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 7 	 7
# 387.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 0 	 7
# 388.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 7 	 7
# 389.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 7 	 7
# 390.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 7 	 7
# 391.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 0 	 7
# 392.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 12 	 7
# 393.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 7 	 7
# 394.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 3 	 7
# 395.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 1 	 7
# 396.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 3 	 7
# 397.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 7 	 7
# 398.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 1 	 7
# 399.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 400.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 0 	 7
# 401.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 12 	 7
# 402.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 12 	 7
# 403.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 404.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 12 	 7
# 405.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 0 	 7
# 406.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 0 	 7
# 407.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 408.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 0 	 7
# 409.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 1 	 7
# 410.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 0 	 7
# 411.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 1 	 7
# 412.) tensor([  4.9169,   4.0631, -13.6777,  ..., -14.3114, -14.5948, -12.8624]) 	 0 	 7
# 413.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 0 	 7
# 414.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 415.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 1 	 7
# 416.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 0 	 7
# 417.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 418.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 0 	 7
# 419.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 420.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 3 	 7
# 421.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 3 	 7
# 422.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 12 	 7
# 423.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 12 	 7
# 424.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 425.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 7 	 7
# 426.) tensor([  4.8579,   4.0129, -13.5109,  ..., -14.1374, -14.4191, -12.7073]) 	 7 	 7
# 427.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 428.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 0 	 7
# 429.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 0 	 7
# 430.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 1 	 7
# 431.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 7 	 7
# 432.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 7 	 7
# 433.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 0 	 7
# 434.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 1 	 7
# 435.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 0 	 7
# 436.) tensor([  4.8627,   4.0169, -13.5244,  ..., -14.1515, -14.4335, -12.7200]) 	 12 	 7
# 437.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 1 	 7
# 438.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 1 	 7
# 439.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 440.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 0 	 7
# 441.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 0 	 7
# 442.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 0 	 7
# 443.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 1 	 7
# 444.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 0 	 7
# 445.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 7 	 7
# 446.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 3 	 7
# 447.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 3 	 7
# 448.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 3 	 7
# 449.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 450.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 12 	 7
# 451.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 7 	 7
# 452.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 7 	 7
# 453.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 0 	 7
# 454.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 12 	 7
# 455.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 7 	 7
# 456.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 1 	 7
# 457.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 7 	 7
# 458.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 7 	 7
# 459.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 0 	 7
# 460.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 7 	 7
# 461.) tensor([  4.9169,   4.0631, -13.6777,  ..., -14.3114, -14.5948, -12.8624]) 	 7 	 7
# 462.) tensor([  4.8892,   4.0393, -13.5992,  ..., -14.2297, -14.5127, -12.7898]) 	 12 	 7
# 463.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 464.) tensor([  4.8591,   4.0139, -13.5143,  ..., -14.1410, -14.4228, -12.7105]) 	 3 	 7
# 465.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 12 	 7
# 466.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 7 	 7
# 467.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 3 	 7
# 468.) tensor([  4.9133,   4.0601, -13.6675,  ..., -14.3008, -14.5840, -12.8529]) 	 12 	 7
# 469.) tensor([  4.9037,   4.0519, -13.6404,  ..., -14.2724, -14.5552, -12.8276]) 	 0 	 7
# 470.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 7 	 7
# 471.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 12 	 7
# 472.) tensor([  4.9073,   4.0550, -13.6506,  ..., -14.2830, -14.5660, -12.8371]) 	 0 	 7
# 473.) tensor([  4.9085,   4.0560, -13.6539,  ..., -14.2865, -14.5696, -12.8402]) 	 0 	 7
# We got 139 correct!
